# %%
import requests
from pprint import pprint
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json' 
try:
    response = requests.get(url)
    response.raise_for_status()
except:
    print("出錯了")
else:
    pprint(response.json())
# Out:
# [{'act': '1',
#   'ar': '復興南路二段235號前',
#   'aren': 'No.235， Sec. 2， Fuxing S. Rd.',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 26,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:46:15',
#   'latitude': 25.02605,
#   'longitude': 121.5436,
#   'mday': '2024-11-17 13:46:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運科技大樓站',
#   'snaen': 'YouBike2.0_MRT Technology Bldg. Sta.',
#   'sno': '500101001',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 28,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '復興南路二段273號西側',
#   'aren': 'No.273， Sec. 2， Fuxing S. Rd. (West)',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:14',
#   'latitude': 25.02565,
#   'longitude': 121.54357,
#   'mday': '2024-11-17 13:51:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_復興南路二段273號前',
#   'snaen': 'YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.',
#   'sno': '500101002',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 21,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路二段96巷7號',
#   'aren': 'No. 7， Ln. 96， Sec. 2， Heping E. Rd',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:47:15',
#   'latitude': 25.02429,
#   'longitude': 121.54124,
#   'mday': '2024-11-17 13:47:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_國北教大實小東側門',
#   'snaen': 'YouBike2.0_NTUE Experiment Elementary School (East)',
#   'sno': '500101003',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 16,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路二段118巷33號',
#   'aren': 'No. 33， Ln. 118， Sec. 2， Heping E. Rd',
#   'available_rent_bikes': 9,
#   'available_return_bikes': 2,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.02351,
#   'longitude': 121.54282,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_和平公園東側',
#   'snaen': 'YouBike2.0_Heping Park (East)',
#   'sno': '500101004',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 11,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '復興南路二段368號',
#   'aren': 'No. 368， Sec. 2， Fuxing S. Rd.',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:17',
#   'latitude': 25.02153,
#   'longitude': 121.54299,
#   'mday': '2024-11-17 13:45:17',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_辛亥復興路口西北側',
#   'snaen': 'YouBike2.0_Xinhai Fuxing Rd. Intersection (Northwest)',
#   'sno': '500101005',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 16,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '復興南路二段280號',
#   'aren': 'No. 280， Sec. 2， Fuxing S. Rd.',
#   'available_rent_bikes': 19,
#   'available_return_bikes': 8,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.02429,
#   'longitude': 121.54328,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_復興南路二段280號前',
#   'snaen': 'YouBike2.0_No. 280， Sec. 2， Fuxing S. Rd.',
#   'sno': '500101006',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 27,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '復興南路二段342號',
#   'aren': 'No. 342， Sec. 2， Fuxing S. Rd.',
#   'available_rent_bikes': 3,
#   'available_return_bikes': 8,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02253,
#   'longitude': 121.54326,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_復興南路二段340巷口',
#   'snaen': 'YouBike2.0_Ln. 340， Sec. 2， Fuxing S. Rd.',
#   'sno': '500101007',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 11,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '新生南路三段52號',
#   'aren': 'No. 52， Sec. 3， Xinsheng S. Rd.',
#   'available_rent_bikes': 8,
#   'available_return_bikes': 9,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.02112,
#   'longitude': 121.53407,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_新生南路三段52號前',
#   'snaen': 'YouBike2.0_No. 52， Sec. 3， Xinsheng S. Rd.',
#   'sno': '500101008',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 17,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '新生南路三段66號東側',
#   'aren': 'No. 66， Sec. 3， Xinsheng S. Rd. (East)',
#   'available_rent_bikes': 10,
#   'available_return_bikes': 6,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01976,
#   'longitude': 121.53384,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_新生南路三段66號前',
#   'snaen': 'YouBike2.0_No. 66， Sec. 3， Xinsheng S. Rd.',
#   'sno': '500101009',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 16,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '新生南路三段82號',
#   'aren': 'No. 82， Sec. 3， Xinsheng S. Rd.',
#   'available_rent_bikes': 20,
#   'available_return_bikes': 0,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01894,
#   'longitude': 121.53361,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_新生南路三段82號前',
#   'snaen': 'YouBike2.0_No. 82， Sec. 3， Xinsheng S. Rd.',
#   'sno': '500101010',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥路一段30號',
#   'aren': 'No. 30， Sec. 1， Xinhai Rd.',
#   'available_rent_bikes': 6,
#   'available_return_bikes': 2,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:21:15',
#   'latitude': 25.01986,
#   'longitude': 121.52982,
#   'mday': '2024-11-17 13:21:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_辛亥路一段30號前',
#   'snaen': 'YouBike2.0_No. 30， Sec. 1， Xinhai Rd.',
#   'sno': '500101012',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 8,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '復興南路二段236號',
#   'aren': 'No. 236， Sec. 2， Fuxing S. Rd.',
#   'available_rent_bikes': 7,
#   'available_return_bikes': 2,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02543,
#   'longitude': 121.54332,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_和平復興路口西北側',
#   'snaen': 'YouBike2.0_Heping Fuxing Rd. Intersection (Northwest)',
#   'sno': '500101013',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 9,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '羅斯福路三段311號',
#   'aren': 'No. 311， Sec. 3， Roosevelt Rd.',
#   'available_rent_bikes': 10,
#   'available_return_bikes': 1,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.01717,
#   'longitude': 121.53202,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_羅斯福路三段311號前',
#   'snaen': 'YouBike2.0_No. 311， Sec. 3， Roosevelt Rd.',
#   'sno': '500101014',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 11,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '敦南街76巷28號',
#   'aren': 'No. 28， Ln. 76， Dunnan St.',
#   'available_rent_bikes': 11,
#   'available_return_bikes': 3,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.020348,
#   'longitude': 121.546446,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_大安運動中心停車場',
#   'snaen': 'YouBike2.0_Taipei Da-an Sports Center Parking lot',
#   'sno': '500101015',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 14,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '羅斯福路三段245號',
#   'aren': 'No. 245， Sec. 3， Roosevelt Rd.',
#   'available_rent_bikes': 7,
#   'available_return_bikes': 1,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:17',
#   'latitude': 25.01927,
#   'longitude': 121.52989,
#   'mday': '2024-11-17 13:50:17',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_羅斯福路三段245號前',
#   'snaen': 'YouBike2.0_No. 245， Sec. 3， Roosevelt Rd.',
#   'sno': '500101016',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 8,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '羅斯福路三段283巷11號',
#   'aren': 'No. 11， Ln. 283， Sec. 3， Roosevelt Rd.',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 0,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01895,
#   'longitude': 121.53156,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_溫州公園',
#   'snaen': 'YouBike2.0_Wenzhou Park',
#   'sno': '500101018',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 5,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臥龍街1號',
#   'aren': 'No. 1， Wolong St.',
#   'available_rent_bikes': 3,
#   'available_return_bikes': 21,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:40:15',
#   'latitude': 25.024461,
#   'longitude': 121.546705,
#   'mday': '2024-11-17 13:40:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_和平臥龍街口',
#   'snaen': 'YouBike2.0_Heping Wolong St. Intersection',
#   'sno': '500101019',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 24,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '0',
#   'ar': '新生南路三段54巷/溫州街口',
#   'aren': 'Ln. 54， Sec. 3， Xinsheng S. Rd. & Wenzhou St. Intersection',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 5,
#   'infoDate': '2024-11-01',
#   'infoTime': '2024-11-01 03:48:14',
#   'latitude': 25.02093,
#   'longitude': 121.5331,
#   'mday': '2024-11-01 03:48:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_溫州停車場',
#   'snaen': 'YouBike2.0_Wenzhou Parking Lot',
#   'sno': '500101020',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 5,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '羅斯福路四段21號旁天橋下',
#   'aren': 'No. 21， Sec. 4， Roosevelt Rd.',
#   'available_rent_bikes': 3,
#   'available_return_bikes': 3,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.01385,
#   'longitude': 121.53549,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_銘傳國小側門',
#   'snaen': 'YouBike2.0_Taipei Municipal MingChuan Elementary School(Side Gate)',
#   'sno': '500101021',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 7,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '捷運公館站(2號出口)外側',
#   'aren': 'MRT Gongguan Sta. (Exit 2)',
#   'available_rent_bikes': 87,
#   'available_return_bikes': 5,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01491,
#   'longitude': 121.53438,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運公館站(2號出口)',
#   'snaen': 'YouBike2.0_MRT Gongguan Sta. (Exit 2)',
#   'sno': '500101022',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 99,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '羅斯福路四段107號(西南側)',
#   'aren': 'No. 107， Sec. 4， Roosevelt Rd.(Southwest)',
#   'available_rent_bikes': 21,
#   'available_return_bikes': 4,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:14',
#   'latitude': 25.01244,
#   'longitude': 121.53661,
#   'mday': '2024-11-17 13:51:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_第二學生活動中心',
#   'snaen': 'YouBike2.0_2nd Student Activity Center',
#   'sno': '500101023',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 25,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆路四段43號(臺灣科技大學正門旁小側門靠田徑場)',
#   'aren': 'No. 43， Sec. 4， Keelung Rd.',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 45,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.01451,
#   'longitude': 121.54142,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺灣科技大學正門',
#   'snaen': 'YouBike2.0_NTUST(Main Gate)',
#   'sno': '500101024',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 50,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆路四段73巷與基隆路口',
#   'aren': 'Ln. 73， Sec. 4， Keelung Rd. Intersection',
#   'available_rent_bikes': 8,
#   'available_return_bikes': 90,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.01295,
#   'longitude': 121.53973,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺灣科技大學側門',
#   'snaen': 'YouBike2.0_NTUST(Side Gate)',
#   'sno': '500101025',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 99,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '羅斯福路四段113巷基隆路四段41巷口',
#   'aren': 'Ln. 113， Sec. 4， Roosevelt Rd. & Ln. 41， Sec. 4， Keelung Rd. '
#           'Intersection',
#   'available_rent_bikes': 2,
#   'available_return_bikes': 28,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:40:16',
#   'latitude': 25.01137,
#   'longitude': 121.54062,
#   'mday': '2024-11-17 13:40:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_公館公園',
#   'snaen': 'YouBike2.0_Gongguan Park',
#   'sno': '500101026',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 30,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆路四段41巷68弄臺科帆船大樓旁',
#   'aren': 'Aly. 68， Ln. 41， Sec. 4， Keelung Rd.',
#   'available_rent_bikes': 10,
#   'available_return_bikes': 29,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01182,
#   'longitude': 121.54165,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺灣科技大學後門',
#   'snaen': 'YouBike2.0_NTUST(Back Gate)',
#   'sno': '500101027',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 39,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆路三段155巷57號西側',
#   'aren': 'No. 57， Ln. 155， Sec. 3， Keelung Rd.(West)',
#   'available_rent_bikes': 3,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:41:15',
#   'latitude': 25.01426,
#   'longitude': 121.54382,
#   'mday': '2024-11-17 13:41:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大醫學院附設癌醫中心',
#   'snaen': 'YouBike2.0_NTU Cancer Center',
#   'sno': '500101028',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '芳蘭路/基隆路三段155巷口',
#   'aren': 'Fanglan Rd & Ln. 155， Sec. 3， Keelung Rd. Intersection',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 11,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:16',
#   'latitude': 25.01234,
#   'longitude': 121.54503,
#   'mday': '2024-11-17 13:45:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大環研大樓',
#   'snaen': 'YouBike2.0_NTU Environment Research Building',
#   'sno': '500101029',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 15,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '芳蘭路51號西北側',
#   'aren': 'No. 51， Fanglan Rd.(Northwest)',
#   'available_rent_bikes': 7,
#   'available_return_bikes': 26,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.0136,
#   'longitude': 121.54656,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大永齡生醫工程館',
#   'snaen': 'YouBike2.0_NTU Yonglin Biomedical Engineering Hall',
#   'sno': '500101030',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 34,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '長興街/長興街80巷口西側',
#   'aren': 'Ln. 80， Changxing St. Intersection(West)',
#   'available_rent_bikes': 6,
#   'available_return_bikes': 14,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01537,
#   'longitude': 121.54698,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大男七舍前',
#   'snaen': "YouBike2.0_NTU 7th Men's Dorm",
#   'sno': '500101031',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '長興街50號西北側',
#   'aren': 'No. 50， Changxing St.(Northwest)',
#   'available_rent_bikes': 2,
#   'available_return_bikes': 59,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.01637,
#   'longitude': 121.54535,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大男一舍前',
#   'snaen': "YouBike2.0_NTU 1st Men's Dorm",
#   'sno': '500101032',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 61,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '大安區長興街31號',
#   'aren': 'No. 31， Changxing St.',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 40,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:35:16',
#   'latitude': 25.01664,
#   'longitude': 121.5452,
#   'mday': '2024-11-17 13:35:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大男六舍前',
#   'snaen': "YouBike2.0_NTU 6th Men's Dorm",
#   'sno': '500101033',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 40,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆路三段155巷/基隆路四段口',
#   'aren': 'Ln. 155， Sec. 3， Keelung Rd. Intersection',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 18,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:19:15',
#   'latitude': 25.01576,
#   'longitude': 121.54291,
#   'mday': '2024-11-17 13:19:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大動物醫院前',
#   'snaen': 'YouBike2.0_NTU Veterinary Hospital',
#   'sno': '500101034',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 18,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥路三段188號',
#   'aren': 'No. 188， Sec. 3， Xinhai Rd.',
#   'available_rent_bikes': 14,
#   'available_return_bikes': 10,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:41:15',
#   'latitude': 25.01787,
#   'longitude': 121.5476,
#   'mday': '2024-11-17 13:41:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大土木研究大樓前',
#   'snaen': 'YouBike2.0_NTU Civil Engineering Research Building',
#   'sno': '500101035',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 24,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大萬才館北側',
#   'aren': 'NTU Wan Tsai Research Hall',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02032,
#   'longitude': 121.54497,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大萬才館前',
#   'snaen': 'YouBike2.0_NTU Wan Tsai Research Hall',
#   'sno': '500101036',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥路三段30號西北側',
#   'aren': 'No. 30， Sec. 3， Xinhai Rd.(Northwest)',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 19,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:42:15',
#   'latitude': 25.02076,
#   'longitude': 121.54432,
#   'mday': '2024-11-17 13:42:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大國青大樓宿舍前',
#   'snaen': 'YouBike2.0_NTU Guo - Ching Building',
#   'sno': '500101037',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥路與復興南路口西南側',
#   'aren': 'Xinhai Fuxing Rd. Intersection (Southwest)',
#   'available_rent_bikes': 7,
#   'available_return_bikes': 20,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:16',
#   'latitude': 25.02101,
#   'longitude': 121.54284,
#   'mday': '2024-11-17 13:45:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大社科院圖書館前',
#   'snaen': 'YouBike2.0_NTU College of social Sciences Building',
#   'sno': '500101038',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 27,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大法人語言訓練中心北側',
#   'aren': 'NTU Language Training & Testing Center(North)',
#   'available_rent_bikes': 12,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.02104,
#   'longitude': 121.54081,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大法人語言訓練中心前',
#   'snaen': 'YouBike2.0_NTU Language Training & Testing Center',
#   'sno': '500101039',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 28,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大綜合體育館北側',
#   'aren': 'NTU Sports Center(North)',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 21,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.0222,
#   'longitude': 121.53626,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺大綜合體育館停車場前',
#   'snaen': 'YouBike2.0_NTU Sports Center Car Park',
#   'sno': '500101040',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 25,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥新生路口東南側',
#   'aren': 'Xinhai Xinsheng Rd. Intersection (Southeast)',
#   'available_rent_bikes': 22,
#   'available_return_bikes': 28,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.02218,
#   'longitude': 121.53474,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_辛亥新生路口東南側',
#   'snaen': 'YouBike2.0_Xinhai Xinsheng Rd. Intersection (Southeast)',
#   'sno': '500101041',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 50,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆長興路口東側',
#   'aren': 'Keelung Changxing Rd. Intersection(East)',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 15,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:48:16',
#   'latitude': 25.01727,
#   'longitude': 121.54471,
#   'mday': '2024-11-17 13:48:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_基隆長興路口東側',
#   'snaen': 'YouBike2.0_Keelung Changxing Rd. Intersection(East)',
#   'sno': '500101042',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 15,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '敦南街51號',
#   'aren': 'No. 51， Dunnan St.',
#   'available_rent_bikes': 11,
#   'available_return_bikes': 23,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.022864,
#   'longitude': 121.546622,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_國北教大側門南側',
#   'snaen': 'YouBike2.0_NTUE Side Gate(South)',
#   'sno': '500101091',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 34,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '敦南街73號',
#   'aren': 'No. 73， Dunnan St.',
#   'available_rent_bikes': 7,
#   'available_return_bikes': 18,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:22:15',
#   'latitude': 25.021641,
#   'longitude': 121.54704,
#   'mday': '2024-11-17 13:22:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_和平實小東北側',
#   'snaen': 'YouBike2.0_Heping Experiment Elementary School (Northeast)',
#   'sno': '500101092',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 25,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥路三段15號',
#   'aren': 'No. 15， Sec. 1， Xinhai Rd.',
#   'available_rent_bikes': 7,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:36:15',
#   'latitude': 25.021469,
#   'longitude': 121.544069,
#   'mday': '2024-11-17 13:36:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_大安區健康服務中心',
#   'snaen': 'YouBike2.0_Daan District Public Health Center',
#   'sno': '500101093',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 23,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥泰順街口東南側',
#   'aren': 'Xinhai Taishun St. Intersection (Southeast)',
#   'available_rent_bikes': 16,
#   'available_return_bikes': 4,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02193,
#   'longitude': 121.53165,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_辛亥泰順街口',
#   'snaen': 'YouBike2.0_Xinhai Taishun St. Intersection',
#   'sno': '500101094',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臥龍街170號(前)',
#   'aren': 'No. 170， Wolong St.',
#   'available_rent_bikes': 11,
#   'available_return_bikes': 26,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:16',
#   'latitude': 25.0189,
#   'longitude': 121.55013,
#   'mday': '2024-11-17 13:45:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_芳和國中',
#   'snaen': 'YouBike2.0_Fanghe Junior High School',
#   'sno': '500101095',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 37,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臥龍街234-2號',
#   'aren': 'No. 234-2， Wolong St.',
#   'available_rent_bikes': 24,
#   'available_return_bikes': 17,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:43:15',
#   'latitude': 25.01856,
#   'longitude': 121.55558,
#   'mday': '2024-11-17 13:43:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臥龍樂業街口',
#   'snaen': 'YouBike2.0_Wolong Leye St. Intersection',
#   'sno': '500101097',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 41,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥路三段223號西側',
#   'aren': 'No. 223， Sec. 3， Xinhai Rd. (West)',
#   'available_rent_bikes': 17,
#   'available_return_bikes': 8,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:38:15',
#   'latitude': 25.01623,
#   'longitude': 121.55037,
#   'mday': '2024-11-17 13:38:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臥龍公園',
#   'snaen': 'YouBike2.0_Wolong Park',
#   'sno': '500101098',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 25,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '樂業街101巷3號西北側',
#   'aren': 'No. 3， Ln. 101， Leye St. (Northwest)',
#   'available_rent_bikes': 38,
#   'available_return_bikes': 5,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:48:14',
#   'latitude': 25.021,
#   'longitude': 121.55211,
#   'mday': '2024-11-17 13:48:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_嘉興公園',
#   'snaen': 'YouBike2.0_Jiaxing Park',
#   'sno': '500101099',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 44,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路三段420號東北側',
#   'aren': 'No. 420， Sec. 3， Heping E. Rd. (Northeast)',
#   'available_rent_bikes': 26,
#   'available_return_bikes': 23,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:48:14',
#   'latitude': 25.0181,
#   'longitude': 121.55929,
#   'mday': '2024-11-17 13:48:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運麟光站(2號出口)',
#   'snaen': 'YouBike2.0_MRT Linguang Sta. (Exit 2)',
#   'sno': '500101100',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 50,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路三段410號',
#   'aren': 'No. 410， Sec. 3， Heping E. Rd.',
#   'available_rent_bikes': 44,
#   'available_return_bikes': 19,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.02397,
#   'longitude': 121.55266,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運六張犁站',
#   'snaen': 'YouBike2.0_MRT Liuzhangli Sta.',
#   'sno': '500101101',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 64,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆路二段166號',
#   'aren': 'No. 166， Sec. 2， Keelung Rd.',
#   'available_rent_bikes': 3,
#   'available_return_bikes': 19,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:38:14',
#   'latitude': 25.02705,
#   'longitude': 121.55551,
#   'mday': '2024-11-17 13:38:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_喬治工商',
#   'snaen': 'YouBike2.0_George Vocational High School of Taipei',
#   'sno': '500101102',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 24,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '通化街189號西側',
#   'aren': 'No. 189， Tonghua St. (West)',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 10,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:48:15',
#   'latitude': 25.02694,
#   'longitude': 121.55325,
#   'mday': '2024-11-17 13:48:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_法治公園',
#   'snaen': 'YouBike2.0_Fazhi Park',
#   'sno': '500101103',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 15,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '辛亥路一段/羅斯福路三段口北側(辛亥路側)',
#   'aren': 'Sec. 1， Xinhai Rd & Sec. 3， Roosevelt Rd (North)',
#   'available_rent_bikes': 8,
#   'available_return_bikes': 10,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.02021,
#   'longitude': 121.52942,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運臺電大樓站(2號出口)',
#   'snaen': 'YouBike2.0_MRT Taipower Building Sta. (Exit 2)',
#   'sno': '500101104',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 18,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路一段/金山南路二段西南側',
#   'aren': 'Sec. 1， Heping E. Rd & Sec. 2， Jinshan S. Rd Intersection '
#           '(Southwest)',
#   'available_rent_bikes': 17,
#   'available_return_bikes': 28,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02669,
#   'longitude': 121.52529,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_和平金山路口',
#   'snaen': 'YouBike2.0_Sec. 1， Heping E. Rd & Sec. 2， Jinshan S. Rd '
#            'Intersection',
#   'sno': '500101105',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 45,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路一段/龍泉街口西南側',
#   'aren': 'Sec. 1， Heping E. Rd & Longquan St. Intersection (Southwest)',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 30,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02638,
#   'longitude': 121.52971,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_和平龍泉街口',
#   'snaen': 'YouBike2.0_Sec. 1， Heping E. Rd & Longquan St. Intersection',
#   'sno': '500101107',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 34,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路一段/泰順街口東南側',
#   'aren': 'Sec. 1， Heping E. Rd & Taishun St  Intersection (Southeast)',
#   'available_rent_bikes': 2,
#   'available_return_bikes': 7,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02621,
#   'longitude': 121.53171,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_和平泰順街口',
#   'snaen': 'YouBike2.0_Sec. 1， Heping E. Rd & Taishun St  Intersection',
#   'sno': '500101108',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 9,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路一段129號前',
#   'aren': 'No. 129， Sec. 1， Heping E. Rd.',
#   'available_rent_bikes': 37,
#   'available_return_bikes': 1,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.0266,
#   'longitude': 121.52973,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺灣師範大學(圖書館)',
#   'snaen': 'YouBike2.0_National Taiwan Normal University (library)',
#   'sno': '500101109',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 40,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '羅斯福路二段41號前',
#   'aren': 'No. 41， Sec. 2， Roosevelt Rd',
#   'available_rent_bikes': 26,
#   'available_return_bikes': 33,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:14',
#   'latitude': 25.0276,
#   'longitude': 121.52217,
#   'mday': '2024-11-17 13:51:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運古亭站(6號出口)',
#   'snaen': 'YouBike2.0_MRT Guting Sta. (Exit 6)',
#   'sno': '500101110',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 60,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '和平東路一段19號前',
#   'aren': 'No. 19， Sec. 1， Heping E. Rd',
#   'available_rent_bikes': 2,
#   'available_return_bikes': 11,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.02715,
#   'longitude': 121.52293,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運古亭站(5號出口)',
#   'snaen': 'YouBike2.0_MRT Guting Sta. (Exit 5)',
#   'sno': '500101111',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 14,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '建國南路二段/建國南路二段151巷(橋下空間)',
#   'aren': 'Sec. 2， Jianguo S. Rd & Ln. 151， Sec. 2， Jianguo S. Rd (Under '
#           'Bridge)',
#   'available_rent_bikes': 41,
#   'available_return_bikes': 10,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.02895,
#   'longitude': 121.5379,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臺北市立圖書館(總館)',
#   'snaen': 'YouBike2.0_Taipei Public library',
#   'sno': '500101113',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 51,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '新生南路二段與和平東路二段口東北側',
#   'aren': 'Sec. 2， Xinsheng S. Rd & Sec. 2， Heping E. Rd (Northeast)',
#   'available_rent_bikes': 16,
#   'available_return_bikes': 35,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02657,
#   'longitude': 121.53515,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_新生和平路口東北側',
#   'snaen': 'YouBike2.0_Sec. 2， Xinsheng S. Rd & Sec. 2， Heping E. Rd '
#            'Intersection',
#   'sno': '500101114',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 51,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '建國南路二段與和平東路二段口西北側',
#   'aren': 'Sec. 2， Jianguo S. Rd & Sec. 2， Heping E. Rd. (Northwest)',
#   'available_rent_bikes': 33,
#   'available_return_bikes': 15,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02606,
#   'longitude': 121.53738,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_建國和平路口西北側',
#   'snaen': 'YouBike2.0_Sec. 2， Jianguo S. Rd & Sec. 2， Heping E. Rd '
#            'Intersection',
#   'sno': '500101115',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 50,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '金華街249號對面',
#   'aren': 'No. 249， Jinhua St. (Opposite)',
#   'available_rent_bikes': 23,
#   'available_return_bikes': 20,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.02984,
#   'longitude': 121.53107,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_金華公園',
#   'snaen': 'YouBike2.0_Jinhua Park',
#   'sno': '500101116',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 44,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '信義路二段128號前',
#   'aren': 'No. 128， Sec. 2， Xinyi Rd.',
#   'available_rent_bikes': 2,
#   'available_return_bikes': 13,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.03383,
#   'longitude': 121.52815,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運東門站(3號出口)',
#   'snaen': 'YouBike2.0_MRT Dongmen Sta. (Exit 3)',
#   'sno': '500101117',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 15,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '信義路二段與杭州南路二段東南側',
#   'aren': 'Sec. 2， Xinyi Rd. & Sec. 2， Hangzhou S. Rd. (Southeast)',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 11,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.03519,
#   'longitude': 121.5245,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_金甌女中',
#   'snaen': "YouBike2.0_Jin'ou Girls High School",
#   'sno': '500101118',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 12,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '愛國東路21巷與杭州南路二段25巷口東南側',
#   'aren': 'Ln. 21， Aiguo E. Rd. & Ln. 25， Sec. 2， Hangzhou S. Rd. Intersection '
#           '(Southeast)',
#   'available_rent_bikes': 3,
#   'available_return_bikes': 17,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:46:15',
#   'latitude': 25.03325,
#   'longitude': 121.52436,
#   'mday': '2024-11-17 13:46:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_金杭公園',
#   'snaen': 'YouBike2.0_Jinhang Park',
#   'sno': '500101119',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '愛國東路與杭州南路二段口西南側',
#   'aren': 'Aiguo E. Rd. & Sec. 2， Hangzhou S. Rd. Intersection (Southwest)',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 42,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:16',
#   'latitude': 25.03164,
#   'longitude': 121.52661,
#   'mday': '2024-11-17 13:49:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_愛國金山路口',
#   'snaen': 'YouBike2.0_Aiguo & Jinshan Rd. Intersection',
#   'sno': '500101120',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 43,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '敦化南路二段293巷口南側',
#   'aren': 'Ln. 293， Sec. 2， Dunhua S. Rd. (South)',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 9,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.0237,
#   'longitude': 121.54899,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_敦化南路二段293巷口南側',
#   'snaen': 'YouBike2.0_Ln. 293， Sec. 2， Dunhua S. Rd (South)',
#   'sno': '500101122',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 14,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '敦化南路二段218號',
#   'aren': 'No. 218， Sec. 2， Dunhua S. Rd',
#   'available_rent_bikes': 9,
#   'available_return_bikes': 29,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.02215,
#   'longitude': 121.54839,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_敦化基隆路口',
#   'snaen': 'YouBike2.0_Sec. 2， Dunhua S. Rd & Sec. 2， Keelung Rd Intersection',
#   'sno': '500101123',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 38,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '安和路二段185號',
#   'aren': 'No185， Sec. 2， Anhe Rd',
#   'available_rent_bikes': 20,
#   'available_return_bikes': 9,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:44:15',
#   'latitude': 25.02721,
#   'longitude': 121.54988,
#   'mday': '2024-11-17 13:44:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_安和路二段181巷口',
#   'snaen': 'YouBike2.0_Ln. 181， Sec. 2， Anhe Rd',
#   'sno': '500101124',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 29,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '通化街111號',
#   'aren': 'No. 101， Tonghua St.',
#   'available_rent_bikes': 23,
#   'available_return_bikes': 6,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.02952,
#   'longitude': 121.55406,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臨江街夜市(通化街101巷口)',
#   'snaen': 'YouBike2.0_Linjiang St night market (Ln. 101， Tonghua St)',
#   'sno': '500101125',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 30,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '基隆路二段108號',
#   'aren': 'No. 108， Sec. 2， Keelung Rd.',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 23,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:37:14',
#   'latitude': 25.02931,
#   'longitude': 121.55721,
#   'mday': '2024-11-17 13:37:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_臨江街夜市(基隆路)',
#   'snaen': 'YouBike2.0_Linjiang St night market (Keelung Rd)',
#   'sno': '500101126',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 29,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '忠孝東路三段81號',
#   'aren': 'No. 81， Sec. 3， Zhongxiao E. Rd.',
#   'available_rent_bikes': 21,
#   'available_return_bikes': 24,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.04177,
#   'longitude': 121.53833,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_台北科技大學億光大樓',
#   'snaen': 'YouBike2.0_National Taipei University of Technology (Everlight '
#            'Building)',
#   'sno': '500101127',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 45,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '新生南路一段113號',
#   'aren': 'No. 113， Ln. 119， Sec. 1， Xinsheng S. Rd.',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 32,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:16',
#   'latitude': 25.04003,
#   'longitude': 121.53299,
#   'mday': '2024-11-17 13:49:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_新生南路一段119巷口',
#   'snaen': 'YouBike2.0_Ln. 119， Sec. 1， Xinsheng S. Rd Intersection',
#   'sno': '500101128',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 33,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '仁愛路三段22號',
#   'aren': "No. 22， Sec. 3， Ren'ai Rd.",
#   'available_rent_bikes': 16,
#   'available_return_bikes': 10,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.03753,
#   'longitude': 121.53523,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_幸安國小(仁愛路)',
#   'snaen': "YouBike2.0_Xing'an Elementary School (Ren'ai Rd)",
#   'sno': '500101129',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 28,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '建國南路一段304巷45號南側',
#   'aren': 'No. 45， Ln. 304， Sec. 1， Jianguo S. Rd. (South)',
#   'available_rent_bikes': 8,
#   'available_return_bikes': 7,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:46:15',
#   'latitude': 25.03534,
#   'longitude': 121.5354,
#   'mday': '2024-11-17 13:46:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_民榮公園',
#   'snaen': 'YouBike2.0_Minrong Park',
#   'sno': '500101130',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 15,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '復興南路一段信義路三段147巷45弄口',
#   'aren': 'Sec. 1， Fuxing S. Rd & Aly. 45， Ln. 147， Sec. 3， Xinyi Rd '
#           'Intersection.',
#   'available_rent_bikes': 37,
#   'available_return_bikes': 13,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.03701,
#   'longitude': 121.54348,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_復興南路1段340巷口',
#   'snaen': 'YouBike2.0_Ln. 340， Sec. 1， Fuxing S. Rd Intersection',
#   'sno': '500101131',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 50,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '建國南路一段/濟南路三段口(東南側)',
#   'aren': 'Sec. 1， Jianguo S. Rd & Sec. 3， Jinan Rd Intersection. (Southeast)',
#   'available_rent_bikes': 25,
#   'available_return_bikes': 29,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.03935,
#   'longitude': 121.53828,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_建國濟南路口',
#   'snaen': 'YouBike2.0_Sec. 1， Jianguo S. Rd & Sec. 3， Jinan Rd Intersection',
#   'sno': '500101132',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 54,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '復興南路一段/仁愛路三段123巷13弄(西北側)',
#   'aren': "Sec. 1， Fuxing S. R & Aly. 13， Ln. 123， Sec. 3， Ren'ai Rd. "
#           '(Northwest)',
#   'available_rent_bikes': 42,
#   'available_return_bikes': 1,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.04035,
#   'longitude': 121.5436,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運忠孝復興站(2號出口)',
#   'snaen': 'YouBike2.0_MRT Zhongxiao Fuxing Sta (Exit 2)',
#   'sno': '500101133',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 43,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '信義路4段6號(前)',
#   'aren': 'No. 6， Sec. 4， Xinyi Rd.',
#   'available_rent_bikes': 6,
#   'available_return_bikes': 7,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.0332,
#   'longitude': 121.5439,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運大安站(4號出口)',
#   'snaen': 'YouBike2.0_MRT Da’an Sta (Exit 4)',
#   'sno': '500101134',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 13,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '信義路3段143號(前)',
#   'aren': 'No. 143， Sec. 3， Xinyi Rd.',
#   'available_rent_bikes': 16,
#   'available_return_bikes': 6,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:46:15',
#   'latitude': 25.03358,
#   'longitude': 121.54141,
#   'mday': '2024-11-17 13:46:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運大安站(2號出口)',
#   'snaen': 'YouBike2.0_MRT Da’an Sta (Exit 2)',
#   'sno': '500101135',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 22,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '信義路四段74號(前)',
#   'aren': 'No. 74， Sec. 4， Xinyi Rd.',
#   'available_rent_bikes': 7,
#   'available_return_bikes': 11,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:51:15',
#   'latitude': 25.03317,
#   'longitude': 121.54639,
#   'mday': '2024-11-17 13:51:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_信義大安路口(信維大樓)',
#   'snaen': 'YouBike2.0_Sec. 4， Xinyi Rd & Da’an Rd Intersection (Xinwei '
#            'Building)',
#   'sno': '500101136',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 18,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '敦化南路一段與敦化南路一段236巷口',
#   'aren': 'Sec. 1， Dunhua S. Rd & Ln. 236， Sec. 1， Dunhua S. Rd Intersection.',
#   'available_rent_bikes': 66,
#   'available_return_bikes': 0,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:47:15',
#   'latitude': 25.04092,
#   'longitude': 121.54825,
#   'mday': '2024-11-17 13:47:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_龍門廣場',
#   'snaen': 'YouBike2.0_Long Men Plaza',
#   'sno': '500101137',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 70,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '仁愛路四段258號前',
#   'aren': "No. 74， Sec. 4， Ren'ai Rd.",
#   'available_rent_bikes': 19,
#   'available_return_bikes': 14,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.03754,
#   'longitude': 121.55285,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_仁愛安和路口',
#   'snaen': "YouBike2.0_Sec. 4， Ren'ai Rd & Sec. 1， Anhe Rd Intersection",
#   'sno': '500101138',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 33,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '信義路四段155號前',
#   'aren': 'No. 155， Sec. 4， Xinyi Rd',
#   'available_rent_bikes': 31,
#   'available_return_bikes': 20,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:43:15',
#   'latitude': 25.03333,
#   'longitude': 121.54977,
#   'mday': '2024-11-17 13:43:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_信義敦化路口',
#   'snaen': 'YouBike2.0_Sec. 4， Xinyi Rd & Sec. 1， Dunhua S. Rd Intersection',
#   'sno': '500101139',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 52,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '安和路一段75號(對面)',
#   'aren': 'No. 75， Sec. 1， Anhe Rd.',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 21,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:39:15',
#   'latitude': 25.03706,
#   'longitude': 121.55166,
#   'mday': '2024-11-17 13:39:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_仁愛國中',
#   'snaen': 'YouBike2.0_Ren Ai Junior High School',
#   'sno': '500101140',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 25,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '信義路四段188號前',
#   'aren': 'No. 188， Sec. 4， Xinyi Rd',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 20,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:41:15',
#   'latitude': 25.03304,
#   'longitude': 121.55171,
#   'mday': '2024-11-17 13:41:15',
#   'sarea': '大安區',
#   'sareaen': 'Daan Dist.',
#   'sna': 'YouBike2.0_捷運信義安和站(2號出口)',
# ...
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 20,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大社科院西側',
#   'aren': 'NTU College of social Sciences Building(West)',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 42,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:17',
#   'latitude': 25.02053,
#   'longitude': 121.54145,
#   'mday': '2024-11-17 13:45:17',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大社科院西側',
#   'snaen': 'YouBike2.0_NTU College of social Sciences Building(West)',
#   'sno': '500119067',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 42,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大社會及社工館南側',
#   'aren': 'NTU Dept. of Sociology / Dept. of Social Work(South)',
#   'available_rent_bikes': 27,
#   'available_return_bikes': 39,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:15',
#   'latitude': 25.01987,
#   'longitude': 121.54175,
#   'mday': '2024-11-17 13:45:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大社會系館南側',
#   'snaen': 'YouBike2.0_NTU Department of Sociology(South)',
#   'sno': '500119068',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 66,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大思亮館東南側',
#   'aren': 'NTU Shih - Liang Hall(Southeast)',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 21,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:46:15',
#   'latitude': 25.02074,
#   'longitude': 121.53906,
#   'mday': '2024-11-17 13:46:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大思亮館東南側',
#   'snaen': 'YouBike2.0_NTU Shih - Liang Hall(Southeast)',
#   'sno': '500119069',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 26,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大椰林小舖旁',
#   'aren': 'NTU Green Cabin',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 47,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01561,
#   'longitude': 121.53583,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大椰林小舖',
#   'snaen': 'YouBike2.0_NTU Green Cabin',
#   'sno': '500119070',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 48,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大計算機網路資訊中心南側',
#   'aren': 'NTU Computer and Information Networking Center(South)',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 30,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:46:15',
#   'latitude': 25.02036,
#   'longitude': 121.53992,
#   'mday': '2024-11-17 13:46:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大計資中心南側',
#   'snaen': 'YouBike2.0_NTU Computer and Information Networking Center(South)',
#   'sno': '500119071',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 34,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大原子與分子科學研究所東北側',
#   'aren': 'NTU Institute of Atomic and Molecular Sciences(Northeast)',
#   'available_rent_bikes': 0,
#   'available_return_bikes': 12,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 12:50:17',
#   'latitude': 25.01881,
#   'longitude': 121.53868,
#   'mday': '2024-11-17 12:50:17',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大原分所北側',
#   'snaen': 'YouBike2.0_NTU Institute of Atomic and Molecular Sciences(North)',
#   'sno': '500119072',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 12,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大動物博物館西側',
#   'aren': 'Museum of Zoology(West)',
#   'available_rent_bikes': 21,
#   'available_return_bikes': 9,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:47:15',
#   'latitude': 25.01548,
#   'longitude': 121.53825,
#   'mday': '2024-11-17 13:47:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大生命科學館西北側',
#   'snaen': 'YouBike2.0_NTU Life Science Building(Northwest)',
#   'sno': '500119074',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 30,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '第一學生活動中心東南側',
#   'aren': 'NTU 1st Student Activity Center(Southeast)',
#   'available_rent_bikes': 30,
#   'available_return_bikes': 8,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01761,
#   'longitude': 121.53995,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大第一活動中心西南側',
#   'snaen': 'YouBike2.0_NTU 1st Student Activity Center(Southwest)',
#   'sno': '500119075',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 48,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大博理館西側',
#   'aren': 'NTU Barry Lam Hall(West)',
#   'available_rent_bikes': 15,
#   'available_return_bikes': 7,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:41:15',
#   'latitude': 25.01922,
#   'longitude': 121.54195,
#   'mday': '2024-11-17 13:41:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大博理館西側',
#   'snaen': 'YouBike2.0_NTU Barry Lam Hall(West)',
#   'sno': '500119076',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 22,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大博雅館西側',
#   'aren': 'NTU Liberal Education Classroom Building(West)',
#   'available_rent_bikes': 16,
#   'available_return_bikes': 38,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:31:16',
#   'latitude': 25.0189,
#   'longitude': 121.536,
#   'mday': '2024-11-17 13:31:16',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大博雅館西側',
#   'snaen': 'YouBike2.0_NTU Liberal Education Classroom Building(West)',
#   'sno': '500119077',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 56,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大森林系學系北側',
#   'aren': 'NTU Forestry Building(North)',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 4,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:50:16',
#   'latitude': 25.01704,
#   'longitude': 121.53888,
#   'mday': '2024-11-17 13:50:16',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大森林館北側',
#   'snaen': 'YouBike2.0_NTU Forestry Building(North)',
#   'sno': '500119078',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 10,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大植物魚類標本館一號館北側',
#   'aren': 'NTU Building No.1(North)',
#   'available_rent_bikes': 9,
#   'available_return_bikes': 10,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:43:15',
#   'latitude': 25.01698,
#   'longitude': 121.53455,
#   'mday': '2024-11-17 13:43:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大一號館',
#   'snaen': 'YouBike2.0_NTU Building No.1',
#   'sno': '500119079',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 19,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大進修教育大樓',
#   'aren': 'NTU Omnium Gatherum Building',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 9,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 12:56:15',
#   'latitude': 25.01539,
#   'longitude': 121.53686,
#   'mday': '2024-11-17 12:56:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大小小福西南側',
#   'snaen': 'YouBike2.0_NTU Xiao Xiao Fu Commissary(Southwest)',
#   'sno': '500119080',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 10,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大雅頌廣場東南側',
#   'aren': 'NTU The Odeum Square(Southeast)',
#   'available_rent_bikes': 2,
#   'available_return_bikes': 24,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:18:15',
#   'latitude': 25.01337,
#   'longitude': 121.53909,
#   'mday': '2024-11-17 13:18:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大教研館北側',
#   'snaen': 'YouBike2.0_NTU Teaching and Research Building(North)',
#   'sno': '500119081',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 26,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大園藝暨景觀學系北側',
#   'aren': 'NTU Department of Horticulture(North)',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 5,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:18:15',
#   'latitude': 25.01703,
#   'longitude': 121.53781,
#   'mday': '2024-11-17 13:18:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大四號館東北側',
#   'snaen': 'YouBike2.0_NTU Building No.4(Northeast)',
#   'sno': '500119082',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 10,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大新生教學館南側',
#   'aren': 'NTU Freshman Classroom Building(South)',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 17,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:16',
#   'latitude': 25.0196,
#   'longitude': 121.53846,
#   'mday': '2024-11-17 13:49:16',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大新生教室南側',
#   'snaen': 'YouBike2.0_NTU Freshman Classroom Building(South)',
#   'sno': '500119083',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 18,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大鄭江樓東南側',
#   'aren': 'NTU Graduate Institute of Journalism(South)',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 39,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:44:14',
#   'latitude': 25.01854,
#   'longitude': 121.54309,
#   'mday': '2024-11-17 13:44:14',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大鄭江樓北側',
#   'snaen': 'YouBike2.0_NTU Tseng Jiang Hall(North)',
#   'sno': '500119084',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 40,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大電機二館南側',
#   'aren': 'NTU E. E. Building No. 2(Southeast)',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 13,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:17',
#   'latitude': 25.01857,
#   'longitude': 121.54247,
#   'mday': '2024-11-17 13:45:17',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大電機二館東南側',
#   'snaen': 'YouBike2.0_NTU E. E. Building No. 2(Southeast)',
#   'sno': '500119085',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 14,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大圖書資訊館北側',
#   'aren': 'NTU Dept. of Library and Information Sciences(North)',
#   'available_rent_bikes': 5,
#   'available_return_bikes': 46,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01804,
#   'longitude': 121.53928,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大圖資系館北側',
#   'snaen': 'YouBike2.0_NTU Dept. of Library and Information Sciences(North)',
#   'sno': '500119086',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 51,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大圖書館西南側',
#   'aren': 'NTU Main Library(Southwest)',
#   'available_rent_bikes': 16,
#   'available_return_bikes': 14,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.0169,
#   'longitude': 121.54031,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大總圖書館西南側',
#   'snaen': 'YouBike2.0_NTU Main Library(Southwest)',
#   'sno': '500119087',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 30,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大霖澤館南側',
#   'aren': 'NTU Tsai Lecture Hall(South)',
#   'available_rent_bikes': 4,
#   'available_return_bikes': 31,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:36:15',
#   'latitude': 25.01995,
#   'longitude': 121.54347,
#   'mday': '2024-11-17 13:36:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大黑森林西側',
#   'snaen': 'YouBike2.0_NTU Black Forest(West)',
#   'sno': '500119088',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 35,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大獸醫系館南側',
#   'aren': 'NTU Dept. of Veterinary Medicine(South)',
#   'available_rent_bikes': 1,
#   'available_return_bikes': 23,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.01791,
#   'longitude': 121.54242,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大獸醫館南側',
#   'snaen': 'YouBike2.0_NTU Dept. of Veterinary Medicine(South)',
#   'sno': '500119089',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 24,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大體育館東側',
#   'aren': 'NTU Sports Center(East)',
#   'available_rent_bikes': 14,
#   'available_return_bikes': 18,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:52:15',
#   'latitude': 25.02112,
#   'longitude': 121.53591,
#   'mday': '2024-11-17 13:52:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大新體育館東南側',
#   'snaen': 'YouBike2.0_NTU Sports Center(Southeast)',
#   'sno': '500119090',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 40,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '明達館北側前空地',
#   'aren': 'NTU Ming - Da Hall (North)',
#   'available_rent_bikes': 2,
#   'available_return_bikes': 16,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:47:15',
#   'latitude': 25.01816,
#   'longitude': 121.54469,
#   'mday': '2024-11-17 13:47:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大明達館北側(員工宿舍)',
#   'snaen': 'YouBike2.0_NTU Ming - Da Hall (Staff Dormitory)',
#   'sno': '500119091',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 18,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大管理學院一館前',
#   'aren': 'NTU Bldg.1 College of Management',
#   'available_rent_bikes': 8,
#   'available_return_bikes': 9,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:40:16',
#   'latitude': 25.01436,
#   'longitude': 121.53828,
#   'mday': '2024-11-17 13:40:16',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大管理學院一館',
#   'snaen': 'YouBike2.0_NTU Bldg.1 College of Management',
#   'sno': '500119092',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 17,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大禮賢樓西側空地',
#   'aren': 'NTU LIxian Hall (West)',
#   'available_rent_bikes': 16,
#   'available_return_bikes': 20,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:44:15',
#   'latitude': 25.01467,
#   'longitude': 121.53765,
#   'mday': '2024-11-17 13:44:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大禮賢樓西側',
#   'snaen': 'YouBike2.0_NTU LIxian Hall (West)',
#   'sno': '500119093',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 36,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大大一女餐廳廣場後方',
#   'aren': "NTU Freshman Women's Dorm Restaurant",
#   'available_rent_bikes': 17,
#   'available_return_bikes': 6,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:49:14',
#   'latitude': 25.01479,
#   'longitude': 121.53494,
#   'mday': '2024-11-17 13:49:14',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大大一女餐廳廣場',
#   'snaen': "YouBike2.0_NTU Freshman Women's Dorm Restaurant",
#   'sno': '500119094',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 40,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大學新館旁',
#   'aren': 'NTU MK Innovation Hall',
#   'available_rent_bikes': 11,
#   'available_return_bikes': 22,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:43:15',
#   'latitude': 25.01944,
#   'longitude': 121.54339,
#   'mday': '2024-11-17 13:43:15',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大學新館',
#   'snaen': 'YouBike2.0_NTU MK Innovation Hall',
#   'sno': '500119095',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 33,
#   'updateTime': '2024-11-17 13:52:52'},
#  {'act': '1',
#   'ar': '臺大水源舍區C棟西側',
#   'aren': 'NTU Shui-Yuan Dorms C (West)',
#   'available_rent_bikes': 9,
#   'available_return_bikes': 90,
#   'infoDate': '2024-11-17',
#   'infoTime': '2024-11-17 13:45:16',
#   'latitude': 25.01547,
#   'longitude': 121.52892,
#   'mday': '2024-11-17 13:45:16',
#   'sarea': '臺大公館校區',
#   'sareaen': 'NTU Dist',
#   'sna': 'YouBike2.0_臺大水源舍區C棟',
#   'snaen': 'YouBike2.0_NTU Shui-Yuan Dorms C',
#   'sno': '500119096',
#   'srcUpdateTime': '2024-11-17 13:52:23',
#   'total': 99,
#   'updateTime': '2024-11-17 13:52:52'}]

# %%
try:
    raise ValueError
    print("發生在raise之後")
except:
    print("出錯了")
else:
    print("沒有錯誤")
# Out:
# 出錯了
